# %%
import pyspedas as sps, numpy as np, math
import pytplot as tplt

#Helper Function

def tplt_options(name, **kwargs):
    tplt.options(name, opt_dict=kwargs)

def tplotbroadcast(f, names, newname):
    datas = [tplt.get_data(n).y for n in names] 
    tplt.store_data(newname, data={'x': tplt.get_data(names[0]).times, 'y': [f(i, datas) for i in range(len(datas[0]))]})
    return newname

# %%
# Figure 1,  Characteristics of KH Waves as Observed by the MMS
# Summary Plot 1,  GSM frame
# 
# # Set time range of interest

date_time_start = '2015-10-16/05:00'
date_time_end = '2015-10-16/16:00'
hours=11

tr = [date_time_start, date_time_end]

# set details of data to be retrieved
probe = '2'
datatype = ['des-moms',  'dis-moms']
level = 'l2'
fgm_datarate = 'srvy'
datarate = 'fast'
coords='gsm'

# %%
# load FGM data
sps.mms.fgm(trange=tr,  probe=probe,  level=level,  data_rate=fgm_datarate,  time_clip=True,  get_fgm_ephemeris=True)

# load FPI data
sps.mms.fpi(trange=tr,  probe=probe,  datatype=datatype,  level = level,  data_rate=datarate,  time_clip=True)

# load EDP data
#mms_load_edp,  trange=tr,  probes=probe,  level = level,  data_rate=datarate,  /time_clip
# Out:
# 23-Oct-23 22:10:16: Loading pydata\mms2\fgm\srvy\l2\2015\10\mms2_fgm_srvy_l2_20151016_v4.18.0.cdf
# 23-Oct-23 22:10:38: Time clip was applied to: mms2_fgm_b_gse_srvy_l2
# 23-Oct-23 22:10:42: Time clip was applied to: mms2_fgm_b_gsm_srvy_l2
# 23-Oct-23 22:10:46: Time clip was applied to: mms2_fgm_b_dmpa_srvy_l2
# 23-Oct-23 22:10:51: Time clip was applied to: mms2_fgm_b_bcs_srvy_l2
# 23-Oct-23 22:10:55: Time clip was applied to: mms2_fgm_flag_srvy_l2
# 23-Oct-23 22:10:55: Time clip was applied to: mms2_fgm_r_gse_srvy_l2
# 23-Oct-23 22:10:55: Time clip was applied to: mms2_fgm_r_gsm_srvy_l2
# 23-Oct-23 22:10:59: Time clip was applied to: mms2_fgm_hirange_srvy_l2
# 23-Oct-23 22:11:04: Time clip was applied to: mms2_fgm_bdeltahalf_srvy_l2
# 23-Oct-23 22:11:08: Time clip was applied to: mms2_fgm_stemp_srvy_l2
# 23-Oct-23 22:11:12: Time clip was applied to: mms2_fgm_etemp_srvy_l2
# 23-Oct-23 22:11:17: Time clip was applied to: mms2_fgm_mode_srvy_l2
# 23-Oct-23 22:11:18: Loaded variables:
# 23-Oct-23 22:11:18: Epoch
# 23-Oct-23 22:11:18: mms2_fgm_b_gse_srvy_l2
# 23-Oct-23 22:11:18: mms2_fgm_b_gsm_srvy_l2
# 23-Oct-23 22:11:18: mms2_fgm_b_dmpa_srvy_l2
# 23-Oct-23 22:11:18: mms2_fgm_b_bcs_srvy_l2
# 23-Oct-23 22:11:18: mms2_fgm_flag_srvy_l2
# 23-Oct-23 22:11:18: Epoch_state
# 23-Oct-23 22:11:18: mms2_fgm_r_gse_srvy_l2
# 23-Oct-23 22:11:18: mms2_fgm_r_gsm_srvy_l2
# 23-Oct-23 22:11:18: mms2_fgm_hirange_srvy_l2
# 23-Oct-23 22:11:18: mms2_fgm_bdeltahalf_srvy_l2
# 23-Oct-23 22:11:18: mms2_fgm_stemp_srvy_l2
# 23-Oct-23 22:11:18: mms2_fgm_etemp_srvy_l2
# 23-Oct-23 22:11:18: mms2_fgm_mode_srvy_l2
# 23-Oct-23 22:11:18: mms2_fgm_b_dmpa_srvy_l2_bvec
# 23-Oct-23 22:11:18: mms2_fgm_b_dmpa_srvy_l2_btot
# 23-Oct-23 22:11:18: mms2_fgm_b_gse_srvy_l2_bvec
# 23-Oct-23 22:11:18: mms2_fgm_b_gse_srvy_l2_btot
# 23-Oct-23 22:11:18: mms2_fgm_b_gsm_srvy_l2_bvec
# 23-Oct-23 22:11:18: mms2_fgm_b_gsm_srvy_l2_btot
# 23-Oct-23 22:11:18: mms2_fgm_b_bcs_srvy_l2_bvec
# 23-Oct-23 22:11:18: mms2_fgm_b_bcs_srvy_l2_btot
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\des-moms\2015\10\mms2_fpi_fast_l2_des-moms_20151016040000_v3.4.0.cdf
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\des-moms\2015\10\mms2_fpi_fast_l2_des-moms_20151016060000_v3.4.0.cdf
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\des-moms\2015\10\mms2_fpi_fast_l2_des-moms_20151016080000_v3.4.0.cdf
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\des-moms\2015\10\mms2_fpi_fast_l2_des-moms_20151016100000_v3.4.0.cdf
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\des-moms\2015\10\mms2_fpi_fast_l2_des-moms_20151016120000_v3.4.0.cdf
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\des-moms\2015\10\mms2_fpi_fast_l2_des-moms_20151016140000_v3.4.0.cdf
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\dis-moms\2015\10\mms2_fpi_fast_l2_dis-moms_20151016040000_v3.4.0.cdf
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\dis-moms\2015\10\mms2_fpi_fast_l2_dis-moms_20151016060000_v3.4.0.cdf
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\dis-moms\2015\10\mms2_fpi_fast_l2_dis-moms_20151016080000_v3.4.0.cdf
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\dis-moms\2015\10\mms2_fpi_fast_l2_dis-moms_20151016100000_v3.4.0.cdf
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\dis-moms\2015\10\mms2_fpi_fast_l2_dis-moms_20151016120000_v3.4.0.cdf
# 23-Oct-23 22:11:18: Loading pydata\mms2\fpi\fast\l2\dis-moms\2015\10\mms2_fpi_fast_l2_dis-moms_20151016140000_v3.4.0.cdf
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:25: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: Time clip returns full data set.
# 23-Oct-23 22:11:26: The name mms2_dis_pitchangdist_lowen_fast is currently not in pytplot
# 23-Oct-23 22:11:26: The name mms2_dis_pitchangdist_miden_fast is currently not in pytplot
# 23-Oct-23 22:11:26: The name mms2_dis_pitchangdist_highen_fast is currently not in pytplot
# 23-Oct-23 22:11:26: Loaded variables:
# 23-Oct-23 22:11:26: Epoch
# 23-Oct-23 22:11:26: Epoch_plus_var
# 23-Oct-23 22:11:26: Epoch_minus_var
# 23-Oct-23 22:11:26: mms2_des_errorflags_fast
# 23-Oct-23 22:11:26: mms2_des_compressionloss_fast
# 23-Oct-23 22:11:26: mms2_des_startdelphi_count_fast
# 23-Oct-23 22:11:26: mms2_des_startdelphi_angle_fast
# 23-Oct-23 22:11:26: mms2_des_pitchangdist_lowen_fast
# 23-Oct-23 22:11:26: mms2_des_pitchangdist_miden_fast
# 23-Oct-23 22:11:26: mms2_des_pitchangdist_highen_fast
# 23-Oct-23 22:11:26: mms2_des_energyspectr_px_fast
# 23-Oct-23 22:11:26: mms2_des_energyspectr_mx_fast
# 23-Oct-23 22:11:26: mms2_des_energyspectr_py_fast
# 23-Oct-23 22:11:26: mms2_des_energyspectr_my_fast
# 23-Oct-23 22:11:26: mms2_des_energyspectr_pz_fast
# 23-Oct-23 22:11:26: mms2_des_energyspectr_mz_fast
# 23-Oct-23 22:11:26: mms2_des_energyspectr_par_fast
# 23-Oct-23 22:11:26: mms2_des_energyspectr_anti_fast
# 23-Oct-23 22:11:26: mms2_des_energyspectr_perp_fast
# 23-Oct-23 22:11:26: mms2_des_energyspectr_omni_fast
# 23-Oct-23 22:11:26: mms2_des_numberdensity_fast
# 23-Oct-23 22:11:26: mms2_des_numberdensity_err_fast
# 23-Oct-23 22:11:26: mms2_des_densityextrapolation_low_fast
# 23-Oct-23 22:11:26: mms2_des_densityextrapolation_high_fast
# 23-Oct-23 22:11:26: mms2_des_bulkv_dbcs_fast
# 23-Oct-23 22:11:26: mms2_des_bulkv_spintone_dbcs_fast
# 23-Oct-23 22:11:26: mms2_des_bulkv_gse_fast
# 23-Oct-23 22:11:26: mms2_des_bulkv_spintone_gse_fast
# 23-Oct-23 22:11:26: mms2_des_bulkv_err_fast
# 23-Oct-23 22:11:26: mms2_des_prestensor_dbcs_fast
# 23-Oct-23 22:11:26: mms2_des_prestensor_gse_fast
# 23-Oct-23 22:11:26: mms2_des_prestensor_err_fast
# 23-Oct-23 22:11:26: mms2_des_temptensor_dbcs_fast
# 23-Oct-23 22:11:26: mms2_des_temptensor_gse_fast
# 23-Oct-23 22:11:26: mms2_des_temptensor_err_fast
# 23-Oct-23 22:11:26: mms2_des_heatq_dbcs_fast
# 23-Oct-23 22:11:26: mms2_des_heatq_gse_fast
# 23-Oct-23 22:11:26: mms2_des_heatq_err_fast
# 23-Oct-23 22:11:26: mms2_des_alpha_fast
# 23-Oct-23 22:11:26: mms2_des_alpha_delta_fast
# 23-Oct-23 22:11:26: mms2_des_energy_fast
# 23-Oct-23 22:11:26: mms2_des_energy_delta_fast
# 23-Oct-23 22:11:26: mms2_des_temppara_fast
# 23-Oct-23 22:11:26: mms2_des_tempperp_fast
# 23-Oct-23 22:11:26: mms2_dis_errorflags_fast
# 23-Oct-23 22:11:26: mms2_dis_compressionloss_fast
# 23-Oct-23 22:11:26: mms2_dis_startdelphi_count_fast
# 23-Oct-23 22:11:26: mms2_dis_startdelphi_angle_fast
# 23-Oct-23 22:11:26: mms2_dis_energyspectr_px_fast
# 23-Oct-23 22:11:26: mms2_dis_energyspectr_mx_fast
# 23-Oct-23 22:11:26: mms2_dis_energyspectr_py_fast
# 23-Oct-23 22:11:26: mms2_dis_energyspectr_my_fast
# 23-Oct-23 22:11:26: mms2_dis_energyspectr_pz_fast
# 23-Oct-23 22:11:26: mms2_dis_energyspectr_mz_fast
# 23-Oct-23 22:11:26: mms2_dis_energyspectr_omni_fast
# 23-Oct-23 22:11:26: mms2_dis_spectr_bg_fast
# 23-Oct-23 22:11:26: mms2_dis_numberdensity_bg_fast
# 23-Oct-23 22:11:26: mms2_dis_numberdensity_fast
# 23-Oct-23 22:11:26: mms2_dis_numberdensity_err_fast
# 23-Oct-23 22:11:26: mms2_dis_densityextrapolation_low_fast
# 23-Oct-23 22:11:26: mms2_dis_densityextrapolation_high_fast
# 23-Oct-23 22:11:26: mms2_dis_bulkv_dbcs_fast
# 23-Oct-23 22:11:26: mms2_dis_bulkv_spintone_dbcs_fast
# 23-Oct-23 22:11:26: mms2_dis_bulkv_gse_fast
# 23-Oct-23 22:11:26: mms2_dis_bulkv_spintone_gse_fast
# 23-Oct-23 22:11:26: mms2_dis_bulkv_err_fast
# 23-Oct-23 22:11:26: mms2_dis_prestensor_dbcs_fast
# 23-Oct-23 22:11:26: mms2_dis_prestensor_gse_fast
# 23-Oct-23 22:11:26: mms2_dis_prestensor_err_fast
# 23-Oct-23 22:11:26: mms2_dis_pres_bg_fast
# 23-Oct-23 22:11:26: mms2_dis_temptensor_dbcs_fast
# 23-Oct-23 22:11:26: mms2_dis_temptensor_gse_fast
# 23-Oct-23 22:11:26: mms2_dis_temptensor_err_fast
# 23-Oct-23 22:11:26: mms2_dis_heatq_dbcs_fast
# 23-Oct-23 22:11:26: mms2_dis_heatq_gse_fast
# 23-Oct-23 22:11:26: mms2_dis_heatq_err_fast
# 23-Oct-23 22:11:26: mms2_dis_energy_fast
# 23-Oct-23 22:11:26: mms2_dis_energy_delta_fast
# 23-Oct-23 22:11:26: mms2_dis_temppara_fast
# 23-Oct-23 22:11:26: mms2_dis_tempperp_fast
# 23-Oct-23 22:11:26: mms2_des_errorflags_fast_moms
# 23-Oct-23 22:11:27: mms2_des_compressionloss_fast_moms
# 23-Oct-23 22:11:27: mms2_dis_errorflags_fast_moms
# 23-Oct-23 22:11:27: mms2_dis_compressionloss_fast_moms
# 23-Oct-23 22:11:27: mms2_des_pitchangdist_avg
# 23-Oct-23 22:11:27: mms2_des_errorflags_fast_moms_flagbars_full
# 23-Oct-23 22:11:27: mms2_des_errorflags_fast_moms_flagbars_main
# 23-Oct-23 22:11:27: mms2_des_errorflags_fast_moms_flagbars_others
# 23-Oct-23 22:11:27: mms2_des_errorflags_fast_moms_flagbars_mini
# 23-Oct-23 22:11:27: mms2_dis_errorflags_fast_moms_flagbars_full
# 23-Oct-23 22:11:27: mms2_dis_errorflags_fast_moms_flagbars_main
# 23-Oct-23 22:11:27: mms2_dis_errorflags_fast_moms_flagbars_others
# 23-Oct-23 22:11:27: mms2_dis_errorflags_fast_moms_flagbars_mini
# ['Epoch',
#  'Epoch_plus_var',
#  'Epoch_minus_var',
#  'mms2_des_errorflags_fast',
#  'mms2_des_compressionloss_fast',
#  'mms2_des_startdelphi_count_fast',
#  'mms2_des_startdelphi_angle_fast',
#  'mms2_des_pitchangdist_lowen_fast',
#  'mms2_des_pitchangdist_miden_fast',
#  'mms2_des_pitchangdist_highen_fast',
#  'mms2_des_energyspectr_px_fast',
#  'mms2_des_energyspectr_mx_fast',
#  'mms2_des_energyspectr_py_fast',
#  'mms2_des_energyspectr_my_fast',
#  'mms2_des_energyspectr_pz_fast',
#  'mms2_des_energyspectr_mz_fast',
#  'mms2_des_energyspectr_par_fast',
#  'mms2_des_energyspectr_anti_fast',
#  'mms2_des_energyspectr_perp_fast',
#  'mms2_des_energyspectr_omni_fast',
#  'mms2_des_numberdensity_fast',
#  'mms2_des_numberdensity_err_fast',
#  'mms2_des_densityextrapolation_low_fast',
#  'mms2_des_densityextrapolation_high_fast',
#  'mms2_des_bulkv_dbcs_fast',
#  'mms2_des_bulkv_spintone_dbcs_fast',
#  'mms2_des_bulkv_gse_fast',
#  'mms2_des_bulkv_spintone_gse_fast',
#  'mms2_des_bulkv_err_fast',
#  'mms2_des_prestensor_dbcs_fast',
#  'mms2_des_prestensor_gse_fast',
#  'mms2_des_prestensor_err_fast',
#  'mms2_des_temptensor_dbcs_fast',
#  'mms2_des_temptensor_gse_fast',
#  'mms2_des_temptensor_err_fast',
#  'mms2_des_heatq_dbcs_fast',
#  'mms2_des_heatq_gse_fast',
#  'mms2_des_heatq_err_fast',
#  'mms2_des_alpha_fast',
#  'mms2_des_alpha_delta_fast',
#  'mms2_des_energy_fast',
#  'mms2_des_energy_delta_fast',
#  'mms2_des_temppara_fast',
#  'mms2_des_tempperp_fast',
#  'mms2_dis_errorflags_fast',
#  'mms2_dis_compressionloss_fast',
#  'mms2_dis_startdelphi_count_fast',
#  'mms2_dis_startdelphi_angle_fast',
#  'mms2_dis_energyspectr_px_fast',
#  'mms2_dis_energyspectr_mx_fast',
#  'mms2_dis_energyspectr_py_fast',
#  'mms2_dis_energyspectr_my_fast',
#  'mms2_dis_energyspectr_pz_fast',
#  'mms2_dis_energyspectr_mz_fast',
#  'mms2_dis_energyspectr_omni_fast',
#  'mms2_dis_spectr_bg_fast',
#  'mms2_dis_numberdensity_bg_fast',
#  'mms2_dis_numberdensity_fast',
#  'mms2_dis_numberdensity_err_fast',
#  'mms2_dis_densityextrapolation_low_fast',
#  'mms2_dis_densityextrapolation_high_fast',
#  'mms2_dis_bulkv_dbcs_fast',
#  'mms2_dis_bulkv_spintone_dbcs_fast',
#  'mms2_dis_bulkv_gse_fast',
#  'mms2_dis_bulkv_spintone_gse_fast',
#  'mms2_dis_bulkv_err_fast',
#  'mms2_dis_prestensor_dbcs_fast',
#  'mms2_dis_prestensor_gse_fast',
#  'mms2_dis_prestensor_err_fast',
#  'mms2_dis_pres_bg_fast',
#  'mms2_dis_temptensor_dbcs_fast',
#  'mms2_dis_temptensor_gse_fast',
#  'mms2_dis_temptensor_err_fast',
#  'mms2_dis_heatq_dbcs_fast',
#  'mms2_dis_heatq_gse_fast',
#  'mms2_dis_heatq_err_fast',
#  'mms2_dis_energy_fast',
#  'mms2_dis_energy_delta_fast',
#  'mms2_dis_temppara_fast',
#  'mms2_dis_tempperp_fast',
#  'mms2_des_errorflags_fast_moms',
#  'mms2_des_compressionloss_fast_moms',
#  'mms2_dis_errorflags_fast_moms',
#  'mms2_dis_compressionloss_fast_moms',
#  'mms2_des_pitchangdist_avg',
#  'mms2_des_errorflags_fast_moms_flagbars_full',
#  'mms2_des_errorflags_fast_moms_flagbars_main',
#  'mms2_des_errorflags_fast_moms_flagbars_others',
#  'mms2_des_errorflags_fast_moms_flagbars_mini',
#  'mms2_dis_errorflags_fast_moms_flagbars_full',
#  'mms2_dis_errorflags_fast_moms_flagbars_main',
#  'mms2_dis_errorflags_fast_moms_flagbars_others',
#  'mms2_dis_errorflags_fast_moms_flagbars_mini']

# %%
# Interpolate all necessary data to FGM cadence
sps.tinterpol('mms'+probe+'_dis_numberdensity_'+datarate,  'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot',  newname='mms'+probe+'_dis_numberdensity_'+fgm_datarate)
sps.tinterpol('mms'+probe+'_des_numberdensity_'+datarate,  'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot',  newname='mms'+probe+'_des_numberdensity_'+fgm_datarate)
sps.tinterpol('mms'+probe+'_dis_temppara_'+datarate,  'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot',  newname='mms'+probe+'_dis_temppara_'+fgm_datarate)
sps.tinterpol('mms'+probe+'_dis_tempperp_'+datarate,  'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot',  newname='mms'+probe+'_dis_tempperp_'+fgm_datarate)
sps.tinterpol('mms'+probe+'_des_temppara_'+datarate,  'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot',  newname='mms'+probe+'_des_temppara_'+fgm_datarate)
sps.tinterpol('mms'+probe+'_des_tempperp_'+datarate,  'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot',  newname='mms'+probe+'_des_tempperp_'+fgm_datarate)
sps.tinterpol('mms'+probe+'_edp_dce_'+coords+'_'+datarate+'_l2',  'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot',  newname='mms'+probe+'_edp_dce_'+coords+'_'+fgm_datarate+'_l2')
sps.tinterpol('mms'+probe+'_dis_bulkv_gse_'+datarate,  'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot',  newname='mms'+probe+'_dis_bulkv_gse_'+fgm_datarate)
sps.tinterpol('mms'+probe+'_des_bulkv_gse_'+datarate,  'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot',  newname='mms'+probe+'_des_bulkv_gse_'+fgm_datarate)


# Rotate velocity data to GSM coordinates
sps.cotrans('mms'+probe+'_dis_bulkv_gse_'+fgm_datarate,  'mms'+probe+'_dis_bulkv_'+coords+'_'+fgm_datarate,  coord_in='gse',  coord_out=coords)
# Out:
# 23-Oct-23 22:12:49: tinterpol (linear) was applied to: mms2_dis_numberdensity_srvy
# 23-Oct-23 22:12:49: tinterpol (linear) was applied to: mms2_des_numberdensity_srvy
# 23-Oct-23 22:12:50: tinterpol (linear) was applied to: mms2_dis_temppara_srvy
# 23-Oct-23 22:12:50: tinterpol (linear) was applied to: mms2_dis_tempperp_srvy
# 23-Oct-23 22:12:50: tinterpol (linear) was applied to: mms2_des_temppara_srvy
# 23-Oct-23 22:12:50: tinterpol (linear) was applied to: mms2_des_tempperp_srvy
# 23-Oct-23 22:12:50: tinterpol error: No pytplot names were provided.
# 23-Oct-23 22:12:50: tinterpol (linear) was applied to: mms2_dis_bulkv_gse_srvy
# 23-Oct-23 22:12:51: tinterpol (linear) was applied to: mms2_des_bulkv_gse_srvy
# 23-Oct-23 22:12:51: ['gse', 'gsm']
# 23-Oct-23 22:12:57: Running transformation: subgse2gsm
# 23-Oct-23 22:12:57: Output variable: mms2_dis_bulkv_gsm_srvy
# 1

# %%
# Calculate average temperatures
tplt.add('mms'+probe+'_dis_tempperp_'+fgm_datarate,  'mms'+probe+'_dis_tempperp_'+fgm_datarate,  new_tvar='mms'+probe+'_dis_2tperp_'+fgm_datarate)
tplt.add('mms'+probe+'_dis_temppara_'+fgm_datarate,  'mms'+probe+'_dis_2tperp_'+fgm_datarate,  new_tvar='mms'+probe+'_dis_tempavg_'+fgm_datarate)
tplotbroadcast(lambda i, d: d[0][i] / 3, ['mms'+probe+'_dis_tempavg_'+fgm_datarate], 'mms'+probe+'_dis_tempavg_'+fgm_datarate)

tplt.add('mms'+probe+'_des_tempperp_'+fgm_datarate,  'mms'+probe+'_des_tempperp_'+fgm_datarate,  new_tvar='mms'+probe+'_des_2tperp_'+fgm_datarate)
tplt.add('mms'+probe+'_des_temppara_'+fgm_datarate,  'mms'+probe+'_des_2tperp_'+fgm_datarate,  new_tvar='mms'+probe+'_des_tempavg_'+fgm_datarate)
ElecT = tplotbroadcast(lambda i, d: d[0][i] / 3, ['mms'+probe+'_des_tempavg_'+fgm_datarate], 'mms'+probe+'_des_tempavg_'+fgm_datarate)

tplt.divide('mms'+probe+'_dis_tempavg_'+fgm_datarate,  'mms'+probe+'_des_tempavg_'+fgm_datarate,  new_tvar='mms'+probe+'_tempratio_'+fgm_datarate)


#Average
'''
tplt.add('mms'+probe+'_dis_tempperp_'+fgm_datarate, 'mms'+probe+'_dis_tempperp_'+fgm_datarate, new_tvar='mms'+probe+'_dis_2tperp_'+fgm_datarate)
tplt.add('mms'+probe+'_dis_temppara_'+fgm_datarate, 'mms'+probe+'_dis_2tperp_'+fgm_datarate, new_tvar='mms'+probe+'_dis_tempavg_'+fgm_datarate)
IonT = tplotbroadcast(lambda i, d: d[0][i] / 3, ['mms'+probe+'_dis_tempavg_'+fgm_datarate], 'mms'+probe+'_dis_tempavg_'+fgm_datarate)
tplt.options(IonT, opt_dict={'ytitle': 'Ion Temperature', 'ysubtitle': '[eV]'})


tplt.add('mms'+probe+'_des_tempperp_'+fgm_datarate, 'mms'+probe+'_des_tempperp_'+fgm_datarate, new_tvar='mms'+probe+'_des_2tperp_'+fgm_datarate)
tplt.add('mms'+probe+'_des_temppara_'+fgm_datarate, 'mms'+probe+'_des_2tperp_'+fgm_datarate, new_tvar='mms'+probe+'_des_tempavg_'+fgm_datarate)
ElecT = tplotbroadcast(lambda i, d: d[0][i] / 3, ['mms'+probe+'_des_tempavg_'+fgm_datarate], 'mms'+probe+'_des_tempavg_'+fgm_datarate)
tplt.options(ElecT, opt_dict={'ytitle': 'Electron Temperature', 'ysubtitle': '[eV]'})

#Temp Ratio
IETRat = 'mms'+probe+'_tempratio_'+fgm_datarate
tplt.divide('mms'+probe+'_dis_tempavg_'+fgm_datarate, 'mms'+probe+'_des_tempavg_'+fgm_datarate, new_tvar=IETRat)
tplt.options(IETRat, 'ytitle', 'Ion/Electron Temp Ratio')

'''
# Out:
# "\ntplt.add('mms'+probe+'_dis_tempperp_'+fgm_datarate, 'mms'+probe+'_dis_tempperp_'+fgm_datarate, new_tvar='mms'+probe+'_dis_2tperp_'+fgm_datarate)\ntplt.add('mms'+probe+'_dis_temppara_'+fgm_datarate, 'mms'+probe+'_dis_2tperp_'+fgm_datarate, new_tvar='mms'+probe+'_dis_tempavg_'+fgm_datarate)\nIonT = tplotbroadcast(lambda i, d: d[0][i] / 3, ['mms'+probe+'_dis_tempavg_'+fgm_datarate], 'mms'+probe+'_dis_tempavg_'+fgm_datarate)\ntplt.options(IonT, opt_dict={'ytitle': 'Ion Temperature', 'ysubtitle': '[eV]'})\n\n\ntplt.add('mms'+probe+'_des_tempperp_'+fgm_datarate, 'mms'+probe+'_des_tempperp_'+fgm_datarate, new_tvar='mms'+probe+'_des_2tperp_'+fgm_datarate)\ntplt.add('mms'+probe+'_des_temppara_'+fgm_datarate, 'mms'+probe+'_des_2tperp_'+fgm_datarate, new_tvar='mms'+probe+'_des_tempavg_'+fgm_datarate)\nElecT = tplotbroadcast(lambda i, d: d[0][i] / 3, ['mms'+probe+'_des_tempavg_'+fgm_datarate], 'mms'+probe+'_des_tempavg_'+fgm_datarate)\ntplt.options(ElecT, opt_dict={'ytitle': 'Electron Temperature', 'ysubtitle': '[eV]'})\n\n#Temp Ratio\nIETRat = 'mms'+probe+'_tempratio_'+fgm_datarate\ntplt.divide('mms'+probe+'_dis_tempavg_'+fgm_datarate, 'mms'+probe+'_des_tempavg_'+fgm_datarate, new_tvar=IETRat)\ntplt.options(IETRat, 'ytitle', 'Ion/Electron Temp Ratio')\n\n"

# %%
# Calculate magnetic,  plasma,  total pressures
tplt.multiply('mms'+probe+'_dis_tempavg_'+fgm_datarate,  'mms'+probe+'_dis_numberdensity_'+fgm_datarate, new_tvar='mms'+probe+'_ion_plasma_pressure_'+fgm_datarate)
tplotbroadcast(lambda i, d: d[0][i] * math.e*10.**15, ['mms'+probe+'_ion_plasma_pressure_'+fgm_datarate], 'mms'+probe+'_ion_plasma_pressure_'+fgm_datarate)

tplt.multiply('mms'+probe+'_des_tempavg_'+fgm_datarate,  'mms'+probe+'_des_numberdensity_'+fgm_datarate, new_tvar='mms'+probe+'_electron_plasma_pressure_'+fgm_datarate)
tplotbroadcast(lambda i, d: d[0][i] * math.e*10.**15, ['mms'+probe+'_electron_plasma_pressure_'+fgm_datarate], 'mms'+probe+'_electron_plasma_pressure_'+fgm_datarate)

tplt.multiply('mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot',  'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot',  new_tvar='mms'+probe+'_magnetic_pressure_'+fgm_datarate)
tplotbroadcast(lambda i, d: d[0][i] * 10**-9/(2* 4*math.pi*10**-7), ['mms'+probe+'_magnetic_pressure_'+fgm_datarate], 'mms'+probe+'_magnetic_pressure_'+fgm_datarate)

tplt.add('mms'+probe+'_ion_plasma_pressure_'+fgm_datarate,  'mms'+probe+'_electron_plasma_pressure_'+fgm_datarate,  new_tvar='mms'+probe+'_plasma_pressure_'+fgm_datarate)
tplt.add('mms'+probe+'_plasma_pressure_'+fgm_datarate,  'mms'+probe+'_magnetic_pressure_'+fgm_datarate,  new_tvar='mms'+probe+'_total_pressure_'+fgm_datarate)

tplt.store_data('mms'+probe+'_pressures_'+fgm_datarate,  data=['mms'+probe+'_plasma_pressure_'+fgm_datarate, 'mms'+probe+'_magnetic_pressure_'+fgm_datarate, 'mms'+probe+'_total_pressure_'+fgm_datarate])

# Calculate ion and electron plasma betas
tplt.divide('mms'+probe+'_ion_plasma_pressure_'+fgm_datarate,  'mms'+probe+'_magnetic_pressure_'+fgm_datarate,  new_tvar='mms'+probe+'_ion_beta_'+fgm_datarate)
tplt.divide('mms'+probe+'_electron_plasma_pressure_'+fgm_datarate,  'mms'+probe+'_magnetic_pressure_'+fgm_datarate,  new_tvar='mms'+probe+'_electron_beta_'+fgm_datarate)

# Convert location data to RE
tplotbroadcast(lambda i, d: d[0][i] / 6371, ['mms'+probe+'_fgm_r_'+coords+'_'+fgm_datarate+'_l2'], 'mms'+probe+'_fgm_RE_'+coords+'_'+fgm_datarate)
tplt.split_vec('mms'+probe+'_fgm_RE_'+coords+'_'+fgm_datarate)
tplt_options('mms'+probe+'_fgm_RE_'+coords+'_'+fgm_datarate+'_0',  ytitle = 'Xgsm')
tplt_options('mms'+probe+'_fgm_RE_'+coords+'_'+fgm_datarate+'_1',  ytitle = 'Ygsm')
tplt_options('mms'+probe+'_fgm_RE_'+coords+'_'+fgm_datarate+'_2',  ytitle = 'Zgsm')

'''
#Calculate magnetic, plasma, total pressures
tplt.multiply('mms'+probe+'_dis_tempavg_'+fgm_datarate, 'mms'+probe+'_dis_numberdensity_'+fgm_datarate, new_tvar='mms'+probe+'_ion_plasma_pressure_'+fgm_datarate)
tplotbroadcast(lambda i, d: d[0][i] * math.e*10.**15, ['mms'+probe+'_ion_plasma_pressure_'+fgm_datarate], 'mms'+probe+'_ion_plasma_pressure_'+fgm_datarate)

tplt.multiply('mms'+probe+'_des_tempavg_'+fgm_datarate, 'mms'+probe+'_des_numberdensity_'+fgm_datarate, new_tvar='mms'+probe+'_electron_plasma_pressure_'+fgm_datarate)
tplotbroadcast(lambda i, d: d[0][i] * math.e*10.**15, ['mms'+probe+'_electron_plasma_pressure_'+fgm_datarate], 'mms'+probe+'_electron_plasma_pressure_'+fgm_datarate)

tplt.multiply('mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot', 'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot', new_tvar='mms'+probe+'_magnetic_pressure_'+fgm_datarate)
tplotbroadcast(lambda i, d: d[0][i] * 10**-9/(2* 4*math.pi*10**-7), ['mms'+probe+'_magnetic_pressure_'+fgm_datarate], 'mms'+probe+'_magnetic_pressure_'+fgm_datarate)

#Calculate ion and electron plasma betas
IonB = 'mms'+probe+'_ion_beta_'+fgm_datarate
ElecB = 'mms'+probe+'_electron_beta_'+fgm_datarate
tplt.divide('mms'+probe+'_ion_plasma_pressure_'+fgm_datarate, 'mms'+probe+'_magnetic_pressure_'+fgm_datarate, new_tvar=IonB)
tplt.divide('mms'+probe+'_electron_plasma_pressure_'+fgm_datarate,'mms'+probe+'_magnetic_pressure_'+fgm_datarate, new_tvar=ElecB)
tplt.options(IonB, 'ytitle', 'Ion Plasma Beta')
tplt.options(ElecB, 'ytitle', 'Electron Plasma Beta')


# Convert location data to RE
tplotbroadcast(lambda i, d: d[0][i] / 6371, ['mms'+probe+'_fgm_r_'+coords+'_'+fgm_datarate+'_l2'], 'mms'+probe+'_fgm_RE_'+coords+'_'+fgm_datarate)
'''
# Out:
# "\n#Calculate magnetic, plasma, total pressures\ntplt.multiply('mms'+probe+'_dis_tempavg_'+fgm_datarate, 'mms'+probe+'_dis_numberdensity_'+fgm_datarate, new_tvar='mms'+probe+'_ion_plasma_pressure_'+fgm_datarate)\ntplotbroadcast(lambda i, d: d[0][i] * math.e*10.**15, ['mms'+probe+'_ion_plasma_pressure_'+fgm_datarate], 'mms'+probe+'_ion_plasma_pressure_'+fgm_datarate)\n\ntplt.multiply('mms'+probe+'_des_tempavg_'+fgm_datarate, 'mms'+probe+'_des_numberdensity_'+fgm_datarate, new_tvar='mms'+probe+'_electron_plasma_pressure_'+fgm_datarate)\ntplotbroadcast(lambda i, d: d[0][i] * math.e*10.**15, ['mms'+probe+'_electron_plasma_pressure_'+fgm_datarate], 'mms'+probe+'_electron_plasma_pressure_'+fgm_datarate)\n\ntplt.multiply('mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot', 'mms'+probe+'_fgm_b_'+coords+'_'+fgm_datarate+'_l2_btot', new_tvar='mms'+probe+'_magnetic_pressure_'+fgm_datarate)\ntplotbroadcast(lambda i, d: d[0][i] * 10**-9/(2* 4*math.pi*10**-7), ['mms'+probe+'_magnetic_pressure_'+fgm_datarate], 'mms'+probe+'_magnetic_pressure_'+fgm_datarate)\n\n#Calculate ion and electron plasma betas\nIonB = 'mms'+probe+'_ion_beta_'+fgm_datarate\nElecB = 'mms'+probe+'_electron_beta_'+fgm_datarate\ntplt.divide('mms'+probe+'_ion_plasma_pressure_'+fgm_datarate, 'mms'+probe+'_magnetic_pressure_'+fgm_datarate, new_tvar=IonB)\ntplt.divide('mms'+probe+'_electron_plasma_pressure_'+fgm_datarate,'mms'+probe+'_magnetic_pressure_'+fgm_datarate, new_tvar=ElecB)\ntplt.options(IonB, 'ytitle', 'Ion Plasma Beta')\ntplt.options(ElecB, 'ytitle', 'Electron Plasma Beta')\n\n\n# Convert location data to RE\ntplotbroadcast(lambda i, d: d[0][i] / 6371, ['mms'+probe+'_fgm_r_'+coords+'_'+fgm_datarate+'_l2'], 'mms'+probe+'_fgm_RE_'+coords+'_'+fgm_datarate)\n"

# %%
Ionspec = 'mms'+probe+'_dis_energyspectr_omni_'+datarate
BGSM = 'mms'+probe+'_fgm_b_'+coords+'_srvy_l2'
VGSM = 'mms'+probe+'_dis_bulkv_'+coords+'_'+fgm_datarate
IonT = 'mms'+probe+'_dis_tempavg_'+fgm_datarate
ElecT = 'mms'+probe+'_des_tempavg_'+fgm_datarate
IonN = 'mms'+probe+'_dis_numberdensity_'+fgm_datarate
ElecN = 'mms'+probe+'_des_numberdensity_'+fgm_datarate
IETRat = 'mms'+probe+'_tempratio_'+fgm_datarate
Pres = 'mms'+probe+'_pressures_'+fgm_datarate
IonB = 'mms'+probe+'_ion_beta_'+fgm_datarate
ElecB = 'mms'+probe+'_electron_beta_'+fgm_datarate

tplt_options('mms'+probe+'_total_pressure_'+fgm_datarate,  labels='Total')
tplt_options('mms'+probe+'_plasma_pressure_'+fgm_datarate,  colors='b')
tplt_options('mms'+probe+'_plasma_pressure_'+fgm_datarate,  labels='Plasma')
tplt_options('mms'+probe+'_magnetic_pressure_'+fgm_datarate,  colors='r')
tplt_options('mms'+probe+'_magnetic_pressure_'+fgm_datarate,  labels='Magnetic')

tplt_options(Ionspec,  ytitle = 'Omnidirectional Ion Energy')
tplt_options(BGSM,  ytitle = 'FGM B-Field GSM')
tplt_options(BGSM,  ysubtitle = '[nT]')
tplt_options(VGSM,  ytitle = 'Ion Velocity GSM')
tplt_options(VGSM,  ysubtitle = '[kms=True]')
tplt_options(IonT,  ytitle = 'Ion Temperature')
tplt_options(IonT,  ysubtitle = '[eV]')
tplt_options(IonN,  ytitle='Ion Density')
tplt_options(IonN,  ysubtitle = '[cc=True]')
tplt_options(IonN,  ylog=1)
tplt_options(ElecT,  ytitle = 'Electron Temperature')
tplt_options(ElecT,  ysubtitle = '[eV]')
tplt_options(ElecN,  ytitle = 'Electron Density')
tplt_options(ElecN,  ysubtitle = '[cc=True]')
tplt_options(ElecN,  ylog=1)
tplt_options(IETRat,  ytitle = 'IonElectron=True Temp Ratio')
tplt_options(Pres,  ytitle = 'Total Pressure')
tplt_options(Pres,  ysubtitle = '[nPa]')
tplt_options(IonB,  ytitle = 'Ion Plasma Beta')
tplt_options(ElecB,  ytitle = 'Electron Plasma Beta')

tplt_options(BGSM,  labflag=1)
tplt_options(VGSM,  labflag=1)
tplt_options(IonN,  labflag=3,  labpos=[0])
tplt_options(IonT,  labflag=3,  labpos=[1])
tplt_options(ElecN,  labflag=3,  labpos=[4])


tplt.tplot([Ionspec,BGSM,VGSM,IonT,Pres, IonN], combine_axes=True)

tplt.tplot(['mms'+probe+'_fgm_RE_'+coords+'_'+fgm_datarate+'_2', 'mms'+probe+'_fgm_RE_'+coords+'_'+fgm_datarate+'_1', 'mms'+probe+'_fgm_RE_'+coords+'_'+fgm_datarate+'_0'])
